# %%
import numpy as np
import pandas as pd
from sklearn.manifold import TSNE
import seaborn as sns

# %%
dataframe = pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/iris.data')

# %%
X = dataframe.drop(columns='Name')
y = dataframe['Name']

# %%
tsne = TSNE(n_components=2)

# %%
df_transform = tsne.fit_transform(X)

# %%
coluns_name  = {0:'t_sne_1',1:'t_sne_2'}
df_transform = pd.DataFrame(df_transform)
df_transform.rename(columns=coluns_name,inplace=True)

# %%
df_transform['target'] = y

# %%
df_transform
# Out:
#        t_sne_1   t_sne_2          target
# 0   -23.629887 -3.624824     Iris-setosa
# 1   -26.363739 -4.242057     Iris-setosa
# 2   -26.273161 -2.984760     Iris-setosa
# 3   -26.646650 -3.219558     Iris-setosa
# 4   -23.554888 -3.181660     Iris-setosa
# ..         ...       ...             ...
# 145  13.282291 -1.452854  Iris-virginica
# 146  10.031482 -1.189874  Iris-virginica
# 147  12.318036 -1.299511  Iris-virginica
# 148  12.903381 -3.364756  Iris-virginica
# 149   8.912673 -1.503629  Iris-virginica
#
# [150 rows x 3 columns]

# %%
sns.scatterplot(x='t_sne_1', y='t_sne_2', hue='target', data=df_transform, palette='viridis', s=70)
# Out:
# <Axes: xlabel='t_sne_1', ylabel='t_sne_2'>
