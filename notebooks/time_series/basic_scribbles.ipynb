# %%
import pandas as pd
import plotly.graph_objects as go
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import STL

# %%
df = pd.read_csv('../../data/DailyDelhiClimateTrain.csv')
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df
# Out:
#              meantemp    humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...               ...         ...         ...           ...
# 2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 4 columns]

# %% [markdown]
# ## Plot data

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df.index, y=df.meantemp, mode='lines', name='Temperatures'))
fig.add_trace(go.Scatter(x=df.index, y=df.meanpressure, mode='lines', name='Presure'))
fig.add_trace(go.Scatter(x=df.index, y=df.humidity, mode='lines', name='Humidity'))
fig.add_trace(go.Scatter(x=df.index, y=df.wind_speed, mode='lines', name='Wind speed'))

fig.show()
# Out:
# <div>                            <div id="d1e3a893-1c3c-4648-8bff-8ac2758f2140" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1e3a893-1c3c-4648-8bff-8ac2758f2140")) {                    Plotly.newPlot(                        "d1e3a893-1c3c-4648-8bff-8ac2758f2140",                        [{"mode":"lines","name":"Temperatures","x":["2013-01-01T00:00:00","2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-05T00:00:00","2013-01-06T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-12T00:00:00","2013-01-13T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-19T00:00:00","2013-
# ...

# %%
for column in df.columns:  
    df_colum = df[column]
    res = STL(df_colum).fit()
    res.plot()
    plt.show()
